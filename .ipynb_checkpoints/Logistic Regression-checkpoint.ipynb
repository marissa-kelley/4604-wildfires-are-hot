# %%
import sqlite3
import pandas as pd
import seaborn as sb
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
data = pd.read_csv("filtered_groups_defg.csv")
data.head()
# Out:
# /Users/marissakelley/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0           0        17      17  FS-1418878                FED   FS-FIRESTAT
# 1           1        18      18  FS-1418881                FED   FS-FIRESTAT
# 2           2        40      40  FS-1418920                FED   FS-FIRESTAT
# 3           3       117     119  FS-1419153                FED   FS-FIRESTAT
# 4           4       118     120  FS-1419156                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 0                    FS                USCAENF
# 1                    FS                USCAENF
# 2                    FS                USNCNCF
# 3                    FS                USNENBF
# 4                    FS                USNENBF
#
#              NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 0            Eldorado National Forest                  0503
# 1            Eldorado National Forest                  0503
# 2  National Forests in North Carolina                  0811
# 3            Nebraska National Forest                  0207
# 4            Nebraska National Forest                  0207
#
#                          ...                         FIRE_SIZE_CLASS  \
# 0                        ...                                       G
# 1                        ...                                       G
# 2                        ...                                       D
# 3                        ...                                       D
# 4                        ...                                       D
#
#     LATITUDE   LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY  \
# 0  38.523333 -120.211667        5.0                   USFS    CA      5
# 1  38.780000 -120.260000        5.0                   USFS    CA     17
# 2  36.001667  -81.590000       14.0  MISSING/NOT SPECIFIED    NC     27
# 3  43.899167 -102.954722        5.0                   USFS    SD    103
# 4  43.892778 -102.948056        5.0                   USFS    SD    103
#
#   FIPS_CODE   FIPS_NAME                                              Shape
# 0       5.0      Amador  b'\x00\x01\xad\x10\x00\x00dS\\\xf2\x8b\r^\xc0\...
# 1      17.0   El Dorado  b'\x00\x01\xad\x10\x00\x00p=\n\xd7\xa3\x10^\xc...
# 2      27.0    Caldwell  b'\x00\x01\xad\x10\x00\x00\xf4(\\\x8f\xc2eT\xc...
# 3     103.0  Pennington  b'\x00\x01\xad\x10\x00\x00\x84\xea9+\x1a\xbdY\...
# 4     103.0  Pennington  b'\x00\x01\xad\x10\x00\x00h?:\xf1\xac\xbcY\xc0...
#
# [5 rows x 40 columns]

# %%
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'OBJECTID', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE',
#        'SOURCE_SYSTEM', 'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME',
#        'COMPLEX_NAME', 'FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
#        'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE',
#        'CONT_DOY', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'COUNTY',
#        'FIPS_CODE', 'FIPS_NAME', 'Shape'],
#       dtype='object')

# %%
alt.Chart(data).mark_point().encode(
    x = 'FIRE_YEAR',
    y = 'FIRE_SIZE',
    color = 'NWCG_REPORTING_UNIT_ID'
).interactive()
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/altair/vegalite/v2/api.py in to_dict(self, *args, **kwargs)
#     396         copy = self.copy()
#     397         original_data = getattr(copy, 'data', Undefined)
# --> 398         copy.data = _prepare_data(original_data, context)
#     399
#     400         if original_data is not Undefined:
#
# ~/anaconda3/lib/python3.6/site-packages/altair/vegalite/v2/api.py in _prepare_data(data, context)
#      82     # convert dataframes to dict
#      83     if isinstance(data, pd.DataFrame):
# ---> 84         data = pipe(data, data_transformers.get())
#      85
#      86     # convert string input to a URLData
#
# ~/anaconda3/lib/python3.6/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     550     """
#     551     for func in funcs:
# --> 552         data = func(data)
#     553     return data
#     554
#
# ~/anaconda3/lib/python3.6/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     281     def __call__(self, *args, **kwargs):
#     282         try:
# --> 283             return self._partial(*args, **kwargs)
#     284         except TypeError as exc:
#     285             if self._should_curry(args, kwargs, exc):
#
# ~/anaconda3/lib/python3.6/site-packages/altair/vegalite/data.py in default_data_transformer(data, max_rows)
#      10 @curry
#      11 def default_data_transformer(data, max_rows=5000):
# ---> 12     return pipe(data, limit_rows(max_rows=max_rows), to_values)
#      13
#      14
#
# ~/anaconda3/lib/python3.6/site-packages/toolz/functoolz.py in pipe(data, *funcs)
#     550     """
#     551     for func in funcs:
# --> 552         data = func(data)
#     553     return data
#     554
#
# ~/anaconda3/lib/python3.6/site-packages/toolz/functoolz.py in __call__(self, *args, **kwargs)
#     281     def __call__(self, *args, **kwargs):
#     282         try:
# --> 283             return self._partial(*args, **kwargs)
#     284         except TypeError as exc:
#     285             if self._should_curry(args, kwargs, exc):
#
# ~/anaconda3/lib/python3.6/site-packages/altair/utils/data.py in limit_rows(data, max_rows)
#      70                            'than the maximum allowed ({0}). '
#      71                            'For information on how to plot larger datasets '
# ---> 72                            'in Altair, see the documentation'.format(max_rows))
#      73     return data
#      74
#
# MaxRowsError: The number of rows in your dataset is greater than the maximum allowed (5000). For information on how to plot larger datasets in Altair, see the documentation
# Chart({
#   data:        Unnamed: 0  OBJECTID     FOD_ID             FPA_ID SOURCE_SYSTEM_TYPE  \
#   0               0        17         17         FS-1418878                FED
#   1               1        18         18         FS-1418881                FED
#   2               2        40         40         FS-1418920                FED
#   3               3       117        119         FS-1419153                FED
#   4               4       118        120         FS-1419156                FED
#   5               5       189        192         FS-1419313                FED
#   6               6       549        556         FS-1420078                FED
#   7               7       583        590         FS-1420201                FED
#   8               8       589        596         FS-1420226                FED
#   9               9       590        597         FS-1420228                FED
#   10             10       592        599         FS-1420230                FED
#   11             11       733        742         FS-1420514                FED
#   12             12       736        745         FS-1420517                FED
#   13             13       737        746         FS-1420519                FED
#   14             14       745        757         FS-1420538                FED
#   15             15       772        784         FS-1420566                FED
#   16             16       865        877         FS-1420749                FED
#   17             17       899        911         FS-1420827                FED
#   18             18      1017       1029         FS-1421118                FED
#   19             19      1067       1079         FS-1421247                FED
#   13      FS-FIRESTAT                    FS                USLAKIF
#   14      FS-FIRESTAT                    FS                USMTCGF
#   15      FS-FIRESTAT                    FS                USMTKNF
#   16      FS-FIRESTAT                    FS                USLAKIF
#   17      FS-FIRESTAT                    FS                USLAKIF
#   18      FS-FIRESTAT                    FS                USMTCGF
#   19      FS-FIRESTAT                    FS                USLAKIF
#   20      FS-FIRESTAT                    FS                USNMGNF
#   21      FS-FIRESTAT                    FS                USKSPSF
#   22      FS-FIRESTAT                    FS                USAZASF
#   23      FS-FIRESTAT                    FS                USNENBF
#   24      FS-FIRESTAT                    FS                USKSPSF
#   25      FS-FIRESTAT                    FS                USCOPSF
#   26      FS-FIRESTAT                    FS                USMOMTF
#   27      FS-FIRESTAT                    FS                USCOPSF
#   28      FS-FIRESTAT                    FS                USFLFNF
#   29      FS-FIRESTAT                    FS                USCACNF
#   ...             ...                   ...                    ...
#   54063      ST-CACDF                ST/C&L                USCATUU
#   54064      ST-CACDF                ST/C&L                USCASHU
#   54065      ST-CACDF                ST/C&L                USCAKRN
#   54066      ST-CACDF                ST/C&L                USCAMMU
#   54067      ST-CACDF                ST/C&L                USCAMMU
#   54068      ST-CACDF                ST/C&L                USCABTU
#   54069      ST-CACDF                ST/C&L                USCASKU
#   54070      ST-CACDF                ST/C&L                USCAMMU
#   54071      ST-CACDF                ST/C&L                USCABTU
#   54072      ST-CACDF                ST/C&L                USCAAEU
#   54073      ST-CACDF                ST/C&L                USCALNU
#   54074      ST-CACDF                ST/C&L                USCABEU
#   54075      ST-CACDF                ST/C&L                USCACZU
#   54076      ST-CACDF                ST/C&L                USCALNU
#   54077      ST-CACDF                ST/C&L                USCAKRN
#   54078      ST-CACDF                ST/C&L                USCAVNC
#   54079      ST-CACDF                ST/C&L                USCASCU
#   54080      ST-CACDF                ST/C&L                USCABEU
#   54081      ST-CACDF                ST/C&L                USCABDU
#   54082      ST-CACDF                ST/C&L                USCACZU
#   54083      ST-CACDF                ST/C&L                USCASCU
#   54084      ST-CACDF                ST/C&L                USCANEU
#   54085      ST-CACDF                ST/C&L                USCAMEU
#   54086      ST-CACDF                ST/C&L                USCABTU
#   54087      ST-CACDF                ST/C&L                USCASCU
#   54088      ST-CACDF                ST/C&L                USCAHUU
#   54089      ST-CACDF                ST/C&L                USCAMMU
#   54090      ST-CACDF                ST/C&L                USCALMU
#   54091      ST-CACDF                ST/C&L                USCAMMU
#   54092      ST-CACDF                ST/C&L                USCASCU
#
#                                NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
#   0                            Eldorado National Forest                  0503
#   1                            Eldorado National Forest                  0503
#   2                  National Forests in North Carolina                  0811
#   3                            Nebraska National Forest                  0207
#   4                            Nebraska National Forest                  0207
#   5                               Tonto National Forest                  0312
#   6                             Sequoia National Forest                  0513
#   7                               Tonto National Forest                  0312
#   8                               Tonto National Forest                  0312
#   9                               Tonto National Forest                  0312
#   10                              Tonto National Forest                  0312
#   11                           Santa Fe National Forest                  0310
#   12                    Custer Gallatin National Forest                  0108
#   13                          Kisatchie National Forest                  0806
#   14                    Custer Gallatin National Forest                  0108
#   15                           Kootenai National Forest                  0114
#   16                          Kisatchie National Forest                  0806
#   17                          Kisatchie National Forest                  0806
#   18                    Custer Gallatin National Forest                  0108
#   19                          Kisatchie National Forest                  0806
#   20                               Gila National Forest                  0306
#   21     Pike San Isabel National Forest and Grasslands                  0212
#   22                  Apache-Sitgreaves National Forest                  0301
#   23                           Nebraska National Forest                  0207
#   24     Pike San Isabel National Forest and Grasslands                  0212
#   25                Pike and San Isabel National Forest                  0212
#   26                         Mark Twain National Forest                  0905
#   27                Pike and San Isabel National Forest                  0212
#   28                        National Forests in Florida                  0805
#   29                          Cleveland National Forest                  0502
#   ...                                               ...                   ...
#   54063                                     Tulare Unit                 CATUU
#   54064                             Shasta-Trinity Unit                 CASHU
#   54065                     Kern County Fire Department                 CAKRN
#   54066                            Merced-Mariposa Unit                 CAMMU
#   54067                            Merced-Mariposa Unit                 CAMMU
#   54068                                      Butte Unit                 CABTU
#   54069                                   Siskiyou Unit                 CASKU
#   54070                            Merced-Mariposa Unit                 CAMMU
#   54071                                      Butte Unit                 CABTU
#   54072                           Amador-El Dorado Unit                 CAAEU
#   54073                           Sonoma-Lake Napa Unit                 CALNU
#   54074                        San Benito-Monterey Unit                 CABEU
#   54075                       San Mateo-Santa Cruz Unit                 CACZU
#   54076                           Sonoma-Lake Napa Unit                 CALNU
#   54077                     Kern County Fire Department                 CAKRN
#   54078                  Ventura County Fire Department                 CAVNC
#   54079                                Santa Clara Unit                 CASCU
#   54080                        San Benito-Monterey Unit                 CABEU
#   54081                             San Bernardino Unit                 CABDU
#   54082                       San Mateo-Santa Cruz Unit                 CACZU
#   54083                                Santa Clara Unit                 CASCU
#   54084                         Nevada-Yuba-Placer Unit                 CANEU
#   54085                                  Mendocino Unit                 CAMEU
#   54086                                      Butte Unit                 CABTU
#   54087                                Santa Clara Unit                 CASCU
#   54088                         Humboldt-Del Norte Unit                 CAHUU
#   54089                            Merced-Mariposa Unit                 CAMMU
#   54090                               Lassen-Modoc Unit                 CALMU
#   54091                            Merced-Mariposa Unit                 CAMMU
#   54092                                Santa Clara Unit                 CASCU
#
#                                ...                         FIRE_SIZE_CLASS  \
#   0                            ...                                       G
#   1                            ...                                       G
#   2                            ...                                       D
#   3                            ...                                       D
#   4                            ...                                       D
#   5                            ...                                       G
#   6                            ...                                       F
#   7                            ...                                       F
#   8                            ...                                       E
#   9                            ...                                       E
#   10                           ...                                       F
#   11                           ...                                       E
#   12                           ...                                       D
#   13                           ...                                       E
#   14                           ...                                       F
#   15                           ...                                       E
#   16                           ...                                       D
#   17                           ...                                       D
#   18                           ...                                       E
#   19                           ...                                       D
#   20                           ...                                       D
#   21                           ...                                       E
#   22                           ...                                       E
#   23                           ...                                       D
#   24                           ...                                       E
#   25                           ...                                       D
#   26                           ...                                       D
#   27                           ...                                       E
#   28                           ...                                       D
#   29                           ...                                       D
#   ...                          ...                                     ...
#   54063                        ...                                       E
#   54064                        ...                                       D
#   54065                        ...                                       D
#   54066                        ...                                       D
#   54067                        ...                                       E
#   54068                        ...                                       E
#   54069                        ...                                       D
#   54070                        ...                                       E
#   54071                        ...                                       G
#   54072                        ...                                       D
#   54073                        ...                                       D
#   54074                        ...                                       F
#   54075                        ...                                       E
#   54076                        ...                                       D
#   54077                        ...                                       D
#   54078                        ...                                       D
#   54079                        ...                                       F
#   54080                        ...                                       D
#   54081                        ...                                       E
#   54082                        ...                                       E
#   54083                        ...                                       D
#   54084                        ...                                       E
#   54085                        ...                                       D
#   54086                        ...                                       F
#   54087                        ...                                       D
#   54088                        ...                                       D
#   54089                        ...                                       D
#   54090                        ...                                       F
#   54091                        ...                                       E
#   54092                        ...                                       D
#
#           LATITUDE   LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY  \
#   0      38.523333 -120.211667        5.0                   USFS    CA      5
#   1      38.780000 -120.260000        5.0                   USFS    CA     17
#   2      36.001667  -81.590000       14.0  MISSING/NOT SPECIFIED    NC     27
#   3      43.899167 -102.954722        5.0                   USFS    SD    103
#   4      43.892778 -102.948056        5.0                   USFS    SD    103
#   5      33.723333 -111.275000        5.0                   USFS    AZ      7
#   6      35.688056 -118.438333        5.0                   USFS    CA    NaN
#   7      33.933611 -111.379722        5.0                   USFS    AZ      7
#   8      33.871111 -111.072500        5.0                   USFS    AZ      7
#   9      33.862500 -111.155833        5.0                   USFS    AZ      7
#   10     33.551111 -111.106667        5.0                   USFS    AZ      7
#   11     36.223611 -106.460556        5.0                   USFS    NM     39
#   12     45.744722 -104.180000        5.0                   USFS    MT     11
#   13     31.240278  -92.613056        5.0                   USFS    LA    NaN
#   14     45.308333 -106.358333        5.0                   USFS    MT     87
#   15     48.834167 -115.185000        5.0                   USFS    MT     53
#   16     31.391944  -93.136111        5.0                   USFS    LA    NaN
#   17     31.188889  -92.585833        5.0                   USFS    LA    NaN
#   18     45.370833 -106.241667        5.0                   USFS    MT     75
#   19     31.808611  -92.831944        5.0                   USFS    LA    NaN
#   20     33.216389 -108.100278        5.0                   USFS    NM     17
#   21     37.024722 -101.993333        5.0                   USFS    KS    NaN
#   22     34.457222 -110.749722        5.0                   USFS    AZ     17
#   23     42.983611 -104.025556        5.0                   USFS    NE    165
#   24     36.978056 -102.583056       14.0  MISSING/NOT SPECIFIED    OK    NaN
#   25     37.217222 -103.197778       13.0       STATE OR PRIVATE    CO    NaN
#   26     36.672778  -92.885556       13.0       STATE OR PRIVATE    MO    213
#   27     37.040833 -102.588056        5.0                   USFS    CO    NaN
#   28     30.400833  -84.551389        5.0                   USFS    FL    NaN
#   29     32.681944 -116.640000        5.0                   USFS    CA    NaN
#   ...          ...         ...        ...                    ...   ...    ...
#   54063  35.861762 -118.985630       13.0       STATE OR PRIVATE    CA    NaN
#   54064  40.875955 -121.717781       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54065  35.616666 -118.900000       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54066  37.128714 -119.922494       13.0       STATE OR PRIVATE    CA    NaN
#   54067  37.287216 -120.243087       13.0       STATE OR PRIVATE    CA    NaN
#   54068  39.967083 -121.670017       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54069  41.514841 -122.383031       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54070  37.168791 -119.499888       13.0       STATE OR PRIVATE    CA    NaN
#   54071  39.762464 -121.736696       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54072  38.518181 -121.104004       13.0       STATE OR PRIVATE    CA    NaN
#   54073  38.607831 -122.595851       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54074  36.391049 -121.595123       13.0       STATE OR PRIVATE    CA    NaN
#   54075  37.101910 -121.875700       13.0       STATE OR PRIVATE    CA    NaN
#   54076  38.620332 -122.009153       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54077  35.633333 -118.950000       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54078  34.700000 -118.983333       13.0       STATE OR PRIVATE    CA    NaN
#   54079  37.904877 -121.874159       13.0       STATE OR PRIVATE    CA    NaN
#   54080  36.631359 -121.481988       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54081  34.055406 -117.068987       13.0       STATE OR PRIVATE    CA    NaN
#   54082  36.932050 -121.809000       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54083  37.568733 -121.305283       13.0       STATE OR PRIVATE    CA    NaN
#   54084  38.953216 -121.100584       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54085  39.261827 -123.593129       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54086  39.443241 -121.433033       13.0       STATE OR PRIVATE    CA    NaN
#   54087  37.724917 -121.881111       13.0       STATE OR PRIVATE    CA    NaN
#   54088  40.463517 -124.386817       13.0       STATE OR PRIVATE    CA    NaN
#   54089  37.072713 -119.694152       13.0       STATE OR PRIVATE    CA    NaN
#   54090  40.956983 -121.321236       13.0       STATE OR PRIVATE    CA    NaN
#   54091  37.600389 -120.191168       14.0  MISSING/NOT SPECIFIED    CA    NaN
#   54092  37.222500 -121.808333       14.0  MISSING/NOT SPECIFIED    CA    NaN
#
#         FIPS_CODE     FIPS_NAME  \
#   0           5.0        Amador
#   1          17.0     El Dorado
#   2          27.0      Caldwell
#   3         103.0    Pennington
#   4         103.0    Pennington
#   5           7.0          Gila
#   6           NaN           NaN
#   7           7.0          Gila
#   8           7.0          Gila
#   9           7.0          Gila
#   10          7.0          Gila
#   11         39.0    Rio Arriba
#   12         11.0        Carter
#   13          NaN           NaN
#   14         87.0       Rosebud
#   15         53.0       Lincoln
#   16          NaN           NaN
#   17          NaN           NaN
#   18         75.0  Powder River
#   19          NaN           NaN
#   20         17.0         Grant
#   21          NaN           NaN
#   22         17.0        Navajo
#   23        165.0         Sioux
#   24          NaN           NaN
#   25          NaN           NaN
#   26        213.0         Taney
#   27          NaN           NaN
#   28          NaN           NaN
#   29          NaN           NaN
#   ...         ...           ...
#   54063       NaN           NaN
#   54064       NaN           NaN
#   54065       NaN           NaN
#   54066       NaN           NaN
#   54067       NaN           NaN
#   54068       NaN           NaN
#   54069       NaN           NaN
#   54070       NaN           NaN
#   54071       NaN           NaN
#   54072       NaN           NaN
#   54073       NaN           NaN
#   54074       NaN           NaN
#   54075       NaN           NaN
#   54076       NaN           NaN
#   54077       NaN           NaN
#   54078       NaN           NaN
#   54079       NaN           NaN
#   54080       NaN           NaN
#   54081       NaN           NaN
#   54082       NaN           NaN
#   54083       NaN           NaN
#   54084       NaN           NaN
#   54085       NaN           NaN
#   54086       NaN           NaN
#   54087       NaN           NaN
#   54088       NaN           NaN
#   54089       NaN           NaN
#   54090       NaN           NaN
#   54091       NaN           NaN
#   54092       NaN           NaN
#
#                                                      Shape
#   0      b'\x00\x01\xad\x10\x00\x00dS\\\xf2\x8b\r^\xc0\...
#   1      b'\x00\x01\xad\x10\x00\x00p=\n\xd7\xa3\x10^\xc...
#   2      b'\x00\x01\xad\x10\x00\x00\xf4(\\\x8f\xc2eT\xc...
#   54070  b'\x00\x01\xad\x10\x00\x00h\xea<*\xfe\xdf]\xc0...
#   54071  b'\x00\x01\xad\x10\x00\x00\x04\xc6\xfa\x06&o^\...
#   54072  b'\x00\x01\xad\x10\x00\x00\xcc\xa9d\x00\xa8F^\...
#   54073  b'\x00\x01\xad\x10\x00\x00|\x92;l"\xa6^\xc0`?\...
#   54074  b'\x00\x01\xad\x10\x00\x008\x86\xc7~\x16f^\xc0...
#   54075  b'\x00\x01\xad\x10\x00\x00\xdcF\x03x\x0bx^\xc0...
#   54076  b'\x00\x01\xad\x10\x00\x00@\xeav\xf6\x95\x80^\...
#   54077  b'\x00\x01\xad\x10\x00\x00\xcc\xcc\xcc\xcc\xcc...
#   54078  b'\x00\x01\xad\x10\x00\x00\xf4\x04\x89\xed\xee...
#   54079  b'\x00\x01\xad\x10\x00\x00@ \x978\xf2w^\xc0\x9...
#   54080  b'\x00\x01\xad\x10\x00\x00\x1cD2\xe4\xd8^^\xc0...
#   54081  b'\x00\x01\xad\x10\x00\x00X6sHjD]\xc0P\x007\x8...
#   54082  b'\x00\x01\xad\x10\x00\x00\xb0\x9d\xef\xa7\xc6...
#   54083  b'\x00\x01\xad\x10\x00\x00\x94A\xb5\xc1\x89S^\...
#   54084  b'\x00\x01\xad\x10\x00\x00\x0c\xa0\xdf\xf7oF^\...
#   54085  b'\x00\x01\xad\x10\x00\x00\xc8SV\xd3\xf5\xe5^\...
#   54086  b'\x00\x01\xad\x10\x00\x00\xacE\x0b\xd0\xb6[^\...
#   54087  b'\x00\x01\xad\x10\x00\x00TId\x1fdx^\xc0H\xa8\...
#   54088  b'\x00\x01\xad\x10\x00\x00X"\x17\x9c\xc1\x18_\...
#   54089  b'\x00\x01\xad\x10\x00\x00\xfc\x9c\x82\xfcl\xe...
#   54090  b'\x00\x01\xad\x10\x00\x00\x0c\x93p!\x8fT^\xc0...
#   54091  b'\x00\x01\xad\x10\x00\x00\xa8\x02\xb5\x18<\x0...
#   54092  b'\x00\x01\xad\x10\x00\x00\xc0\xd1U\xba\xbbs^\...
#
#   [54093 rows x 40 columns],
#   encoding: EncodingWithFacet({
#     color: Color({
#       shorthand: 'NWCG_REPORTING_UNIT_ID'
#     }),
#     x: X({
#       shorthand: 'FIRE_YEAR'
#     }),
#     y: Y({
#       shorthand: 'FIRE_SIZE'
#     })
#   }),
#   mark: 'point',
#   selection: SelectionMapping({
#     selector001: SelectionDef({
#       bind: 'scales',
#       encodings: ['x', 'y'],
#       type: 'interval'
#     })
#   })
# })

# %% [markdown]
# ## Logistic Regression

# %%
import matplotlib.pyplot as plt

acc_train = []
acc_test = []

alphas = []
for a in alphas:
    classifier = SGDClassifier(loss='log', alpha=a, max_iter=1000, tol=1.0e-12, random_state=123)
    classifier.fit(X_train, Y_train)
    
    acc_train.append(accuracy_score(Y_train, classifier.predict(X_train)))
    acc_test.append(accuracy_score(Y_test, classifier.predict(X_test)))
    
    # print the predicted probabilities of the first test instance
    print(classifier.predict_proba(X_test)[0])

plt.semilogx(alphas, acc_train, label='Training')
plt.semilogx(alphas, acc_test, label='Test')

plt.xlabel('Alpha')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')

plt.show()
