# %%
import sqlite3
import pandas as pd
import seaborn as sb
import altair as alt
import numpy as np
from multiprocessing import Pool
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %% [markdown]
# # Getting Started

# %%
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("filtered_groups_defg.csv")
# Out:
# /Users/marissakelley/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3018: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Original columns
len(df.columns)
# Out:
# 40

# %%
#dropping columns that will have little to no effect on model performance or contain NaN values
drop_cols = ['Unnamed: 0','OBJECTID', 'FOD_ID', 'FPA_ID','NWCG_REPORTING_UNIT_ID','NWCG_REPORTING_UNIT_NAME','SOURCE_REPORTING_UNIT','SOURCE_REPORTING_UNIT_NAME','LOCAL_FIRE_REPORT_ID','LOCAL_INCIDENT_ID','FIRE_CODE','FIRE_NAME','ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME','COMPLEX_NAME','DISCOVERY_DATE','STAT_CAUSE_CODE','FIPS_CODE', 'FIPS_NAME', 'Shape','OWNER_CODE','DISCOVERY_TIME','COUNTY','CONT_DATE','CONT_DOY','CONT_TIME','SOURCE_SYSTEM','SOURCE_SYSTEM_TYPE']
df = df.drop(columns=drop_cols)

# %%
df_dummies_X = df.drop(columns=['STAT_CAUSE_DESCR'])
df_dummies_X = pd.get_dummies(df_dummies_X)
X = df_dummies_X
Y = df['STAT_CAUSE_DESCR']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.4, random_state=1, stratify=Y)


classifier = LogisticRegression(multi_class='multinomial', solver='lbfgs', random_state=123)

classifier.fit(X_train, Y_train)
training_accuracy = accuracy_score(Y_train, classifier.predict(X_train))
pred = classifier.predict(X_test)
test_accuracy = accuracy_score(Y_test, pred)

print(test_accuracy)
# Out:
# 0.37313984656622606

# %%
# %matplotlib inline
import seaborn as sb
import matplotlib.pyplot as plt
import altair as alt
label_names = sorted(df['STAT_CAUSE_DESCR'].unique())

matrix = confusion_matrix(Y_test, pred)
plt.figure(figsize=(8,8))
sb.heatmap(matrix,square=True,annot=True, fmt='d', cbar=False, cmap='Blues',
          xticklabels=label_names,yticklabels=label_names)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.savefig("logisticregression.png", dpi=170)

# %%
precision_score(Y_test,pred,average='macro')
# Out:
# /Users/marissakelley/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 0.2843726351921244

# %% [markdown]
# ## Learning the weights

# %%
classifier.coef_[0]
# Out:
# array([ 1.08691492e-03, -9.40554379e-04,  1.02428426e-05, -2.28857659e-04,
#         2.62290379e-03,  8.91943695e-06, -3.44926671e-05, -9.08882055e-09,
#        -4.66844482e-07,  0.00000000e+00, -3.05654422e-06, -1.47659089e-06,
#        -1.40813332e-06, -2.57227500e-06,  3.13322665e-05,  3.91824887e-06,
#         3.14806392e-05, -8.31721030e-06, -1.79731642e-05, -4.50245623e-06,
#         6.28926769e-06, -2.36264578e-05, -7.47131798e-08, -9.05137176e-07,
#        -1.36727146e-06,  2.37286519e-05,  2.22906078e-07, -2.33029283e-06,
#         3.88647561e-07,  1.48625327e-05, -3.57572068e-06, -8.51043996e-06,
#        -5.08444531e-07,  4.84170000e-07, -4.38988988e-06, -5.96380912e-06,
#         1.22652199e-05,  6.32436310e-06, -8.29498069e-06, -8.08201471e-06,
#        -3.95734175e-06,  1.19216908e-07,  9.81188208e-09, -1.22817589e-05,
#         2.78685889e-06, -1.04751532e-06, -8.17906439e-07, -1.08642672e-05,
#         1.18096419e-07, -3.01243280e-08, -2.56478637e-06,  1.65318915e-05,
#         2.29394287e-06, -6.69486762e-08,  1.48228153e-06,  1.47655341e-07,
#         1.44562133e-07,  1.46867475e-05,  6.36836583e-06,  1.72618975e-05,
#        -8.04648899e-06,  2.02179521e-06,  1.41021726e-06, -2.14654330e-06,
#        -1.93839270e-08,  5.99256348e-07, -1.13344880e-05, -6.68526716e-06,
#         9.29250215e-08,  1.81546999e-07,  1.77794035e-05, -6.21593184e-06,
#         6.12567274e-07, -9.55950326e-07,  1.09874390e-06, -7.25451474e-06,
#         1.24367879e-05, -2.26150734e-05, -6.34506491e-06,  2.25480394e-06,
#        -3.34649643e-08, -3.12479733e-06,  2.22208809e-08,  1.49351715e-05,
#        -4.55012004e-06])

# %%
df.columns
# Out:
# Index(['NWCG_REPORTING_AGENCY', 'FIRE_YEAR', 'DISCOVERY_DOY',
#        'STAT_CAUSE_DESCR', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'OWNER_DESCR', 'STATE'],
#       dtype='object')

# %%
print("\nFeature weights:")
feature_names = list(df_dummies_X.columns)
for i,a in enumerate(feature_names):
    print(a + ": " + str(classifier.coef_[0][i]))
# Out:
# Feature weights:
# FIRE_YEAR: 0.0010869149156067554
# DISCOVERY_DOY: -0.0009405543787223928
# FIRE_SIZE: 1.0242842625047114e-05
# LATITUDE: -0.0002288576594446636
# LONGITUDE: 0.0026229037915053593
# NWCG_REPORTING_AGENCY_BIA: 8.919436947636355e-06
# NWCG_REPORTING_AGENCY_BLM: -3.4492667105752096e-05
# NWCG_REPORTING_AGENCY_BOR: -9.088820553202739e-09
# NWCG_REPORTING_AGENCY_DOD: -4.668444815551416e-07
# NWCG_REPORTING_AGENCY_DOE: 0.0
# NWCG_REPORTING_AGENCY_FS: -3.056544223034096e-06
# NWCG_REPORTING_AGENCY_FWS: -1.4765908940729037e-06
# NWCG_REPORTING_AGENCY_IA: -1.4081333166424165e-06
# NWCG_REPORTING_AGENCY_NPS: -2.572275000429062e-06
# NWCG_REPORTING_AGENCY_ST/C&L: 3.133226648994227e-05
# NWCG_REPORTING_AGENCY_TRIBE: 3.918248867840236e-06
# FIRE_SIZE_CLASS_D: 3.1480639179996614e-05
# FIRE_SIZE_CLASS_E: -8.317210295694758e-06
# FIRE_SIZE_CLASS_F: -1.797316418718828e-05
# FIRE_SIZE_CLASS_G: -4.502456233734239e-06
# OWNER_DESCR_BIA: 6.289267692974601e-06
# OWNER_DESCR_BLM: -2.3626457754858884e-05
# OWNER_DESCR_BOR: -7.471317983796327e-08
# OWNER_DESCR_COUNTY: -9.051371763032315e-07
# OWNER_DESCR_FWS: -1.3672714562349223e-06
# OWNER_DESCR_MISSING/NOT SPECIFIED: 2.3728651887896935e-05
# OWNER_DESCR_MUNICIPAL/LOCAL: 2.2290607754666997e-07
# OWNER_DESCR_NPS: -2.3302928318521036e-06
# OWNER_DESCR_OTHER FEDERAL: 3.886475611825331e-07
# OWNER_DESCR_PRIVATE: 1.4862532692048591e-05
# OWNER_DESCR_STATE: -3.5757206797285827e-06
# OWNER_DESCR_STATE OR PRIVATE: -8.510439962432908e-06
# OWNER_DESCR_TRIBAL: -5.084445312853627e-07
# OWNER_DESCR_UNDEFINED FEDERAL: 4.841700002085668e-07
# OWNER_DESCR_USFS: -4.3898898759446415e-06
# STATE_AK: -5.963809124014482e-06
# STATE_AL: 1.2265219850275338e-05
# STATE_AR: 6.324363104283901e-06
# STATE_AZ: -8.294980690343593e-06
# STATE_CA: -8.082014710768682e-06
# STATE_CO: -3.9573417506699356e-06
# STATE_CT: 1.1921690821665391e-07
# STATE_DE: 9.81188208431829e-09
# STATE_FL: -1.228175894718673e-05
# STATE_GA: 2.786858893279312e-06
# STATE_HI: -1.0475153206865547e-06
# STATE_IA: -8.179064390080751e-07
# STATE_ID: -1.0864267238029597e-05
# STATE_IL: 1.1809641905895521e-07
# STATE_IN: -3.012432795649888e-08
# STATE_KS: -2.5647863691704086e-06
# STATE_KY: 1.6531891476221227e-05
# STATE_LA: 2.2939428654572603e-06
# STATE_MA: -6.694867617595377e-08
# STATE_MD: 1.48228153100433e-06
# STATE_ME: 1.476553409598824e-07
# STATE_MI: 1.4456213264234396e-07
# STATE_MN: 1.4686747544467427e-05
# STATE_MO: 6.368365830440813e-06
# STATE_MS: 1.7261897468572884e-05
# STATE_MT: -8.046488986184457e-06
# STATE_NC: 2.0217952098668833e-06
# STATE_ND: 1.4102172570936453e-06
# STATE_NE: -2.146543300390252e-06
# STATE_NH: -1.9383927000320407e-08
# STATE_NJ: 5.992563483069364e-07
# STATE_NM: -1.1334487955241853e-05
# STATE_NV: -6.6852671608980045e-06
# STATE_NY: 9.292502151752619e-08
# STATE_OH: 1.8154699877437038e-07
# STATE_OK: 1.7779403467802083e-05
# STATE_OR: -6.215931839532782e-06
# STATE_PA: 6.125672736933537e-07
# STATE_PR: -9.559503256498008e-07
# STATE_SC: 1.0987438958483431e-06
# STATE_SD: -7.254514740609877e-06
# STATE_TN: 1.2436787923766455e-05
# STATE_TX: -2.2615073442531597e-05
# STATE_UT: -6.3450649091581005e-06
# STATE_VA: 2.2548039381711744e-06
# STATE_VT: -3.3464964331815685e-08
# STATE_WA: -3.1247973281884968e-06
# STATE_WI: 2.2220880875111136e-08
# STATE_WV: 1.4935171509461134e-05
# STATE_WY: -4.550120035033581e-06
